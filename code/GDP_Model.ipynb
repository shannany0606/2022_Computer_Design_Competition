# %%
import pandas as pd
from pylab import rcParams
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
from sklearn.metrics import roc_auc_score
from sklearn import metrics 
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures
import statsmodels.formula.api as sm
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler,PowerTransformer,PolynomialFeatures
from sklearn.linear_model import LinearRegression
import operator
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVR

# %% [markdown]
# # GDP回归模型 （美国）

# %%
df=pd.read_csv("/home/mw/input/GDP_data1379/final_data.csv")
df=df[df['LOCATION']=='USA']

# %%
x=[i for i in df['TIME']]
y=[i for i in df['Value'].cumsum()]
x_array=x
y_array=y
x_shape=np.array(df['TIME'][:-1]).reshape(-1, 1)
y_shape=np.array(df['Value'][:-1].cumsum()).reshape(-1, 1)
x=np.asarray(x)
y=np.asarray(y)
x = x[:, np.newaxis]
y = y[:, np.newaxis]
l=int(len(x)*.7)
x_train,x_test=x[:l],x[l:]
y_train,y_test=y[:l],y[l:]

# %% [markdown]
# # 线性回归模型

# %%
polynomial_features= PolynomialFeatures(degree=1)
x_poly = polynomial_features.fit_transform(x)
model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)
rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
plt.scatter(x, y, s=10)
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.xlabel('year') 
plt.ylabel('GDP') 
plt.title('GDP Model-USA')
plt.legend(['Predicted data','Actual data'])
plt.show()
polynomial_features= PolynomialFeatures(degree=1)
x_poly = polynomial_features.fit_transform(x_train)
model = LinearRegression()
model.fit(x_poly, y_train)
x_test_poly=polynomial_features.fit_transform(x_test)
y_poly_pred = model.predict(x_test_poly)
rmse = np.sqrt(mean_squared_error(y_poly_pred,y_test))
r2 = r2_score(y_test,y_poly_pred)
print("RMSE=",rmse)
print("R方=",r2)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/FA257A7B004E4212B818EFDBDC591D5A/rbnag1wz9s.png">
# RMSE= 17.458929128074395
# R方= -0.8808594140868322

# %% [markdown]
# # 二阶多项式回归模型

# %%
polynomial_features= PolynomialFeatures(degree=2)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)
rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
plt.plot(x, y)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.xlabel('year') 
plt.ylabel('GDP') 
plt.title('GDP Model-USA')
plt.legend(['Actual data','Predicted data'])
plt.show()
polynomial_features= PolynomialFeatures(degree=2)
x_poly = polynomial_features.fit_transform(x_train)
model = LinearRegression()
model.fit(x_poly, y_train)
x_test_poly=polynomial_features.fit_transform(x_test)
y_poly_pred = model.predict(x_test_poly)
rmse = np.sqrt(mean_squared_error(y_poly_pred,y_test))
r2 = r2_score(y_test,y_poly_pred)
print("RMSE",rmse)
print("R方=",r2)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/A3747EF923A2473FB985D7A248EF39CE/rbnai7heoy.png">
# RMSE 5.0332103384557465
# R方= 0.8436811716952959

# %%
model.predict(polynomial_features.fit_transform(np.asarray([[2020]])))
# Out:
# array([[228.75532]])

# %% [markdown]
# **2020年美国GDP预测值**

# %% [markdown]
# # 三阶多项式回归模型

# %%
polynomial_features= PolynomialFeatures(degree=3)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)
rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.xlabel('year') 
plt.ylabel('GDP') 
plt.title('GDP Model-USA')
plt.legend(['Predicted data','Actual data'])
plt.show()
polynomial_features= PolynomialFeatures(degree=3)
x_poly = polynomial_features.fit_transform(x_train)
model = LinearRegression()
model.fit(x_poly, y_train)
x_test_poly=polynomial_features.fit_transform(x_test)
y_poly_pred = model.predict(x_test_poly)
rmse = np.sqrt(mean_squared_error(y_poly_pred,y_test))
r2 = r2_score(y_test,y_poly_pred)
print("RMSE=",rmse)
print("R方=",r2)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/099EFFF6A7874653A047AD358B077C34/rbnaj5d083.png">
# RMSE= 4.663959277629773
# R方= 0.8657758597766309

# %%
model.predict(polynomial_features.fit_transform(np.asarray([[2020]])))
# Out:
# array([[235.79812126]])

# %% [markdown]
# # *GDP回归模型（印度）*

# %%
df=pd.read_csv("/home/mw/input/GDP_data1379/final_data.csv")
df=df[df['LOCATION']=='IND']

x=[i for i in df['TIME']]
y=[i for i in df['Value'].cumsum()]
x_array=x
y_array=y
x_shape=np.array(df['TIME'][:-1]).reshape(-1, 1)
y_shape=np.array(df['Value'][:-1].cumsum()).reshape(-1, 1)
x=np.asarray(x)
y=np.asarray(y)
x = x[:, np.newaxis]
y = y[:, np.newaxis]
l=int(len(x)*.8)
x_train,x_test=x[:l],x[l:]
y_train,y_test=y[:l],y[l:]

# %% [markdown]
# # 线性回归模型

# %%
polynomial_features= PolynomialFeatures(degree=1)
x_poly = polynomial_features.fit_transform(x)
model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)
rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
plt.plot(x, y)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.xlabel('year') 
plt.ylabel('GDP') 
plt.title('GDP Model-India')
plt.legend(['Actual data','Predicted data'])
plt.show()
model = linear_model.LinearRegression()
model.fit(x_train,y_train)
y_poly_pred=model.predict(x_test.reshape(-1, 1))
rmse = np.sqrt(mean_squared_error(y_poly_pred,y_test))
r2 = r2_score(y_test,y_poly_pred)
r2 = r2_score(y_test,y_poly_pred)
print("RMSE=",rmse)
print("R方=",r2)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/12484395FB414D2D9164230907F5A585/rbnbaryh0s.png">
# RMSE= 1.4690977523751132
# R方= 0.976664075924686

# %%
model.predict(np.asarray([[2020]]))[0]
# Out:
# array([163.58355946])

# %% [markdown]
# **2020年印度GDP预测值**

# %% [markdown]
# # 二阶多项式回归模型

# %%
polynomial_features= PolynomialFeatures(degree=2)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)
rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.xlabel('year') 
plt.ylabel('GDP') 
plt.title('GDP Model-India')
plt.legend(['Predicted data','Actual data'])
plt.show()
polynomial_features= PolynomialFeatures(degree=2)
x_poly = polynomial_features.fit_transform(x_train)
model = LinearRegression()
model.fit(x_poly, y_train)
x_test_poly=polynomial_features.fit_transform(x_test)
y_poly_pred = model.predict(x_test_poly)
rmse = np.sqrt(mean_squared_error(y_poly_pred,y_test))
r2 = r2_score(y_test,y_poly_pred)
print("RMSE=",rmse)
print("R方=",r2)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/E42AF41D591849F789C1375A533F4F73/rbnbdbzqex.png">
# RMSE= 6.424757047073464
# R方= 0.5536895728711293

# %% [markdown]
# # 三阶多项式回归模型

# %%
polynomial_features= PolynomialFeatures(degree=3)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)
plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.xlabel('year') 
plt.ylabel('GDP') 
plt.title('GDP Model-India')
plt.legend(['Predicted data','Actual data'])
plt.show()
# Out:
# <img src="https://cdn.kesci.com/upload/rt/FA3108C2B7BF424695242E22AF6ED8EE/rbnbdhwzu2.png">

# %% [markdown]
# # *GDP回归模型（南非）*

# %%
df=pd.read_csv("/home/mw/input/GDP_data1379/final_data.csv")
df=df[df['LOCATION']=='ZAF']

x=[i for i in df['TIME']]
y=[i for i in df['Value'].cumsum()]
x_array=x
y_array=y
x_shape=np.array(df['TIME'][:-1]).reshape(-1, 1)
y_shape=np.array(df['Value'][:-1].cumsum()).reshape(-1, 1)
x=np.asarray(x)
y=np.asarray(y)
x = x[:, np.newaxis]
y = y[:, np.newaxis]

l=int(len(x)*.8)
x_train,x_test=x[:l],x[l:]
y_train,y_test=y[:l],y[l:]

# %% [markdown]
# # 二阶多项式回归模型

# %%
polynomial_features= PolynomialFeatures(degree=2)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)
rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.xlabel('year') 
plt.ylabel('GDP') 
plt.title('GDP Model-South Africa')
plt.legend(['Predicted data','Actual data'])
plt.show()
polynomial_features= PolynomialFeatures(degree=2)
x_poly = polynomial_features.fit_transform(x_train)
model = LinearRegression()
model.fit(x_poly, y_train)
x_test_poly=polynomial_features.fit_transform(x_test)
y_poly_pred = model.predict(x_test_poly)
rmse = np.sqrt(mean_squared_error(y_poly_pred,y_test))
r2 = r2_score(y_test,y_poly_pred)
print("RMSE=",rmse)
print("R方=",r2)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/6334CDA0098A4CF09E4115317F9E9659/rbnbe5d47o.png">
# RMSE= 23.63223254512106
# R方= -15.478912371281837

# %%
#对数据进行归一化处理，为SVR奠定基础
scaler=StandardScaler()
dataset={'x':np.asarray(x).reshape(1,len(x))[0],'y':np.asarray(y).reshape(1,len(y))[0]}
df_data=pd.DataFrame(dataset)
normalized = scaler.fit_transform(df_data)
inverse = scaler.inverse_transform(normalized)
tobescaled=[]
for i in range(len(x)):
    tobescaled.append([x[i][0],y[i][0]])
tobescaled=np.asarray(tobescaled)
scaled = scaler.fit_transform(tobescaled)
x_scaled=[]
for i in range(len(x)):
    x_scaled.append([scaled[i][0]])
y_scaled=[]
for i in range(len(y)):
    y_scaled.append(scaled[i][1])

# %% [markdown]
# # 支持向量回归（SVR）

# %%
regressor = SVR(kernel='rbf')
regressor.fit(x_scaled,y_scaled)
y_pred = regressor.predict(x_scaled)
plt.scatter(x_scaled, y_scaled, color = 'magenta')
plt.plot(x_scaled, regressor.predict(x_scaled), color = 'green')
plt.xlabel('year') 
plt.ylabel('GDP') 
plt.title('GDP Model-South Africa')
plt.legend(['Predicted data','Actual data'])
plt.show()
l=int(len(x)*.8)
x_train,x_test=x_scaled[:l],x_scaled[l:]
y_train,y_test=y_scaled[:l],y_scaled[l:]
y_svr_pred=regressor.predict(x_test)
rmse = np.sqrt(mean_squared_error(regressor.predict(x_test),y_test))
r2 = r2_score(y_test,regressor.predict(x_test))
print("RMSE=",rmse)
print("R方=",r2)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/14EF71242CFB475F8C4916FC59511D78/rbnbffx41n.png">
# RMSE= 0.06458733142590245
# R方= 0.7446640595853911

# %%
sc_x=StandardScaler()
sc_x.fit_transform(x)
sc_y=StandardScaler()
sc_y.fit_transform(y)
y_pred = sc_y.inverse_transform ((regressor.predict (sc_x.transform(np.array([[2020]])))))
print(y_pred)
# Out:
# [166.95715873]

# %% [markdown]
# **2020南非GDP预测值**

# %% [markdown]
# # 人工神经网络

# %%
from keras import models, layers
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Out:
# Using TensorFlow backend.

# %%
scaler.fit(x_train)
t1=scaler.transform(x_train)
test_t1=scaler.transform(x_test)
model = models.Sequential()
t2=np.asarray(y_train).reshape(1,len(y_train))[0]

# %%
model.add(layers.Dense(8, activation='relu', input_shape=[np.array(x_train).shape[1]]))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1))
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
history = model.fit(t1,t2, validation_split=0.2, epochs=1000)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 37 samples, validate on 10 samples
# Epoch 1/1000
# 37/37 [==============================] - 0s 4ms/step - loss: 0.9009 - mean_absolute_error: 0.6750 - val_loss: 0.4706 - val_mean_absolute_error: 0.6374
# Epoch 2/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.8267 - mean_absolute_error: 0.6433 - val_loss: 0.4697 - val_mean_absolute_error: 0.6371
# Epoch 3/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.7779 - mean_absolute_error: 0.6215 - val_loss: 0.4656 - val_mean_absolute_error: 0.6343
# Epoch 4/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.7253 - mean_absolute_error: 0.5969 - val_loss: 0.4725 - val_mean_absolute_error: 0.6398
# Epoch 5/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.6850 - mean_absolute_error: 0.5783 - val_loss: 0.4723 - val_mean_absolute_error: 0.6399
# Epoch 6/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.6465 - mean_absolute_error: 0.5588 - val_loss: 0.4749 - val_mean_absolute_error: 0.6420
# Epoch 7/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.6210 - mean_absolute_error: 0.5458 - val_loss: 0.4766 - val_mean_absolute_error: 0.6435
# Epoch 8/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.5953 - mean_absolute_error: 0.5327 - val_loss: 0.4781 - val_mean_absolute_error: 0.6447
# Epoch 9/1000
# 37/37 [==============================] - 0s 57us/step - loss: 0.5719 - mean_absolute_error: 0.5203 - val_loss: 0.4689 - val_mean_absolute_error: 0.6380
# Epoch 10/1000
# 37/37 [==============================] - 0s 59us/step - loss: 0.5524 - mean_absolute_error: 0.5094 - val_loss: 0.4604 - val_mean_absolute_error: 0.6318
# Epoch 11/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.5261 - mean_absolute_error: 0.4940 - val_loss: 0.4590 - val_mean_absolute_error: 0.6308
# Epoch 12/1000
# 37/37 [==============================] - 0s 59us/step - loss: 0.5022 - mean_absolute_error: 0.4801 - val_loss: 0.4598 - val_mean_absolute_error: 0.6316
# Epoch 13/1000
# 37/37 [==============================] - 0s 56us/step - loss: 0.4822 - mean_absolute_error: 0.4690 - val_loss: 0.4602 - val_mean_absolute_error: 0.6320
# Epoch 14/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.4550 - mean_absolute_error: 0.4529 - val_loss: 0.4599 - val_mean_absolute_error: 0.6319
# Epoch 15/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.4356 - mean_absolute_error: 0.4420 - val_loss: 0.4606 - val_mean_absolute_error: 0.6326
# Epoch 16/1000
# 37/37 [==============================] - 0s 59us/step - loss: 0.4111 - mean_absolute_error: 0.4285 - val_loss: 0.4617 - val_mean_absolute_error: 0.6336
# Epoch 17/1000
# 37/37 [==============================] - 0s 58us/step - loss: 0.3879 - mean_absolute_error: 0.4156 - val_loss: 0.4580 - val_mean_absolute_error: 0.6309
# Epoch 18/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.3627 - mean_absolute_error: 0.3995 - val_loss: 0.4551 - val_mean_absolute_error: 0.6288
# Epoch 19/1000
# 37/37 [==============================] - 0s 59us/step - loss: 0.3418 - mean_absolute_error: 0.3868 - val_loss: 0.4504 - val_mean_absolute_error: 0.6254
# Epoch 20/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.3165 - mean_absolute_error: 0.3695 - val_loss: 0.4490 - val_mean_absolute_error: 0.6245
# Epoch 21/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.3014 - mean_absolute_error: 0.3604 - val_loss: 0.4496 - val_mean_absolute_error: 0.6251
# Epoch 22/1000
# 37/37 [==============================] - 0s 57us/step - loss: 0.2799 - mean_absolute_error: 0.3456 - val_loss: 0.4461 - val_mean_absolute_error: 0.6226
# Epoch 23/1000
# 37/37 [==============================] - 0s 57us/step - loss: 0.2643 - mean_absolute_error: 0.3354 - val_loss: 0.4435 - val_mean_absolute_error: 0.6206
# Epoch 24/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.2498 - mean_absolute_error: 0.3245 - val_loss: 0.4288 - val_mean_absolute_error: 0.6093
# Epoch 25/1000
# 37/37 [==============================] - 0s 57us/step - loss: 0.2370 - mean_absolute_error: 0.3143 - val_loss: 0.4280 - val_mean_absolute_error: 0.6088
# Epoch 26/1000
# 37/37 [==============================] - 0s 56us/step - loss: 0.2229 - mean_absolute_error: 0.3044 - val_loss: 0.4225 - val_mean_absolute_error: 0.6044
# Epoch 27/1000
# 37/37 [==============================] - 0s 58us/step - loss: 0.2131 - mean_absolute_error: 0.2965 - val_loss: 0.4113 - val_mean_absolute_error: 0.5956
# Epoch 28/1000
# 37/37 [==============================] - 0s 64us/step - loss: 0.1966 - mean_absolute_error: 0.2829 - val_loss: 0.4113 - val_mean_absolute_error: 0.5958
# Epoch 29/1000
# 37/37 [==============================] - 0s 56us/step - loss: 0.1806 - mean_absolute_error: 0.2704 - val_loss: 0.4133 - val_mean_absolute_error: 0.5976
# Epoch 30/1000
# 37/37 [==============================] - 0s 70us/step - loss: 0.1625 - mean_absolute_error: 0.2552 - val_loss: 0.4102 - val_mean_absolute_error: 0.5952
# Epoch 31/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.1528 - mean_absolute_error: 0.2456 - val_loss: 0.3982 - val_mean_absolute_error: 0.5855
# Epoch 32/1000
# 37/37 [==============================] - 0s 1ms/step - loss: 0.1472 - mean_absolute_error: 0.2398 - val_loss: 0.3848 - val_mean_absolute_error: 0.5745
# Epoch 33/1000
# 37/37 [==============================] - 0s 69us/step - loss: 0.1418 - mean_absolute_error: 0.2333 - val_loss: 0.3814 - val_mean_absolute_error: 0.5717
# Epoch 34/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.1351 - mean_absolute_error: 0.2271 - val_loss: 0.3670 - val_mean_absolute_error: 0.5595
# Epoch 35/1000
# 37/37 [==============================] - 0s 56us/step - loss: 0.1275 - mean_absolute_error: 0.2192 - val_loss: 0.3536 - val_mean_absolute_error: 0.5475
# Epoch 36/1000
# 37/37 [==============================] - 0s 56us/step - loss: 0.1218 - mean_absolute_error: 0.2138 - val_loss: 0.3489 - val_mean_absolute_error: 0.5429
# Epoch 37/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.1164 - mean_absolute_error: 0.2087 - val_loss: 0.3451 - val_mean_absolute_error: 0.5396
# Epoch 38/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.1072 - mean_absolute_error: 0.2004 - val_loss: 0.3406 - val_mean_absolute_error: 0.5356
# Epoch 39/1000
# 37/37 [==============================] - 0s 59us/step - loss: 0.0997 - mean_absolute_error: 0.1946 - val_loss: 0.3379 - val_mean_absolute_error: 0.5334
# Epoch 40/1000
# 37/37 [==============================] - 0s 57us/step - loss: 0.0907 - mean_absolute_error: 0.1871 - val_loss: 0.3303 - val_mean_absolute_error: 0.5265
# Epoch 41/1000
# 37/37 [==============================] - 0s 56us/step - loss: 0.0846 - mean_absolute_error: 0.1820 - val_loss: 0.3237 - val_mean_absolute_error: 0.5204
# Epoch 42/1000
# 37/37 [==============================] - 0s 68us/step - loss: 0.0788 - mean_absolute_error: 0.1761 - val_loss: 0.3182 - val_mean_absolute_error: 0.5153
# Epoch 43/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0749 - mean_absolute_error: 0.1722 - val_loss: 0.3163 - val_mean_absolute_error: 0.5137
# Epoch 44/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0683 - mean_absolute_error: 0.1668 - val_loss: 0.2976 - val_mean_absolute_error: 0.4961
# Epoch 45/1000
# 37/37 [==============================] - 0s 59us/step - loss: 0.0650 - mean_absolute_error: 0.1629 - val_loss: 0.2846 - val_mean_absolute_error: 0.4835
# Epoch 46/1000
# 37/37 [==============================] - 0s 57us/step - loss: 0.0613 - mean_absolute_error: 0.1605 - val_loss: 0.2702 - val_mean_absolute_error: 0.4691
# Epoch 47/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0577 - mean_absolute_error: 0.1573 - val_loss: 0.2559 - val_mean_absolute_error: 0.4541
# Epoch 48/1000
# 37/37 [==============================] - 0s 59us/step - loss: 0.0553 - mean_absolute_error: 0.1536 - val_loss: 0.2487 - val_mean_absolute_error: 0.4465
# Epoch 49/1000
# 37/37 [==============================] - 0s 59us/step - loss: 0.0522 - mean_absolute_error: 0.1509 - val_loss: 0.2520 - val_mean_absolute_error: 0.4500
# Epoch 50/1000
# 37/37 [==============================] - 0s 56us/step - loss: 0.0484 - mean_absolute_error: 0.1490 - val_loss: 0.2473 - val_mean_absolute_error: 0.4449
# Epoch 51/1000
# 37/37 [==============================] - 0s 58us/step - loss: 0.0468 - mean_absolute_error: 0.1460 - val_loss: 0.2496 - val_mean_absolute_error: 0.4474
# Epoch 52/1000
# 37/37 [==============================] - 0s 53us/step - loss: 0.0443 - mean_absolute_error: 0.1458 - val_loss: 0.2402 - val_mean_absolute_error: 0.4372
# Epoch 53/1000
# 37/37 [==============================] - 0s 1ms/step - loss: 0.0421 - mean_absolute_error: 0.1433 - val_loss: 0.2446 - val_mean_absolute_error: 0.4420
# Epoch 54/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0385 - mean_absolute_error: 0.1423 - val_loss: 0.2491 - val_mean_absolute_error: 0.4468
# Epoch 55/1000
# 37/37 [==============================] - 0s 57us/step - loss: 0.0363 - mean_absolute_error: 0.1416 - val_loss: 0.2422 - val_mean_absolute_error: 0.4392
# Epoch 56/1000
# 37/37 [==============================] - 0s 67us/step - loss: 0.0351 - mean_absolute_error: 0.1383 - val_loss: 0.2404 - val_mean_absolute_error: 0.4372
# Epoch 57/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0341 - mean_absolute_error: 0.1380 - val_loss: 0.2429 - val_mean_absolute_error: 0.4398
# Epoch 58/1000
# 37/37 [==============================] - 0s 59us/step - loss: 0.0330 - mean_absolute_error: 0.1353 - val_loss: 0.2299 - val_mean_absolute_error: 0.4254
# Epoch 59/1000
# 37/37 [==============================] - 0s 58us/step - loss: 0.0325 - mean_absolute_error: 0.1335 - val_loss: 0.2308 - val_mean_absolute_error: 0.4261
# Epoch 60/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0319 - mean_absolute_error: 0.1299 - val_loss: 0.2355 - val_mean_absolute_error: 0.4313
# Epoch 61/1000
# 37/37 [==============================] - 0s 66us/step - loss: 0.0304 - mean_absolute_error: 0.1304 - val_loss: 0.2287 - val_mean_absolute_error: 0.4234
# Epoch 62/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0302 - mean_absolute_error: 0.1262 - val_loss: 0.2203 - val_mean_absolute_error: 0.4137
# Epoch 63/1000
# 37/37 [==============================] - 0s 70us/step - loss: 0.0291 - mean_absolute_error: 0.1243 - val_loss: 0.2154 - val_mean_absolute_error: 0.4081
# Epoch 64/1000
# 37/37 [==============================] - 0s 69us/step - loss: 0.0276 - mean_absolute_error: 0.1252 - val_loss: 0.2200 - val_mean_absolute_error: 0.4135
# Epoch 65/1000
# 37/37 [==============================] - 0s 67us/step - loss: 0.0259 - mean_absolute_error: 0.1261 - val_loss: 0.2267 - val_mean_absolute_error: 0.4210
# Epoch 66/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0254 - mean_absolute_error: 0.1229 - val_loss: 0.2308 - val_mean_absolute_error: 0.4255
# Epoch 67/1000
# 37/37 [==============================] - 0s 70us/step - loss: 0.0249 - mean_absolute_error: 0.1213 - val_loss: 0.2322 - val_mean_absolute_error: 0.4271
# Epoch 68/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0244 - mean_absolute_error: 0.1222 - val_loss: 0.2241 - val_mean_absolute_error: 0.4179
# Epoch 69/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0241 - mean_absolute_error: 0.1211 - val_loss: 0.2274 - val_mean_absolute_error: 0.4217
# Epoch 70/1000
# 37/37 [==============================] - 0s 69us/step - loss: 0.0236 - mean_absolute_error: 0.1244 - val_loss: 0.2218 - val_mean_absolute_error: 0.4150
# Epoch 71/1000
# 37/37 [==============================] - 0s 64us/step - loss: 0.0224 - mean_absolute_error: 0.1191 - val_loss: 0.2197 - val_mean_absolute_error: 0.4125
# Epoch 72/1000
# 37/37 [==============================] - 0s 69us/step - loss: 0.0219 - mean_absolute_error: 0.1182 - val_loss: 0.2133 - val_mean_absolute_error: 0.4049
# Epoch 73/1000
# 37/37 [==============================] - 0s 1ms/step - loss: 0.0215 - mean_absolute_error: 0.1173 - val_loss: 0.2181 - val_mean_absolute_error: 0.4104
# Epoch 74/1000
# 37/37 [==============================] - 0s 59us/step - loss: 0.0212 - mean_absolute_error: 0.1157 - val_loss: 0.2180 - val_mean_absolute_error: 0.4103
# Epoch 75/1000
# 37/37 [==============================] - 0s 69us/step - loss: 0.0210 - mean_absolute_error: 0.1143 - val_loss: 0.2191 - val_mean_absolute_error: 0.4115
# Epoch 76/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0206 - mean_absolute_error: 0.1132 - val_loss: 0.2196 - val_mean_absolute_error: 0.4117
# Epoch 77/1000
# 37/37 [==============================] - 0s 70us/step - loss: 0.0203 - mean_absolute_error: 0.1111 - val_loss: 0.2194 - val_mean_absolute_error: 0.4114
# Epoch 78/1000
# 37/37 [==============================] - 0s 68us/step - loss: 0.0199 - mean_absolute_error: 0.1103 - val_loss: 0.2209 - val_mean_absolute_error: 0.4128
# Epoch 79/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0197 - mean_absolute_error: 0.1072 - val_loss: 0.2294 - val_mean_absolute_error: 0.4226
# Epoch 80/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0193 - mean_absolute_error: 0.1124 - val_loss: 0.2386 - val_mean_absolute_error: 0.4328
# Epoch 81/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0187 - mean_absolute_error: 0.1105 - val_loss: 0.2397 - val_mean_absolute_error: 0.4336
# Epoch 82/1000
# 37/37 [==============================] - 0s 64us/step - loss: 0.0182 - mean_absolute_error: 0.1060 - val_loss: 0.2408 - val_mean_absolute_error: 0.4347
# Epoch 83/1000
# 37/37 [==============================] - 0s 56us/step - loss: 0.0180 - mean_absolute_error: 0.1060 - val_loss: 0.2362 - val_mean_absolute_error: 0.4295
# Epoch 84/1000
# 37/37 [==============================] - 0s 59us/step - loss: 0.0179 - mean_absolute_error: 0.1034 - val_loss: 0.2417 - val_mean_absolute_error: 0.4358
# Epoch 85/1000
# 37/37 [==============================] - 0s 70us/step - loss: 0.0176 - mean_absolute_error: 0.1075 - val_loss: 0.2414 - val_mean_absolute_error: 0.4353
# Epoch 86/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0171 - mean_absolute_error: 0.1053 - val_loss: 0.2283 - val_mean_absolute_error: 0.4205
# Epoch 87/1000
# 37/37 [==============================] - 0s 70us/step - loss: 0.0174 - mean_absolute_error: 0.1044 - val_loss: 0.2180 - val_mean_absolute_error: 0.4086
# Epoch 88/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0177 - mean_absolute_error: 0.1017 - val_loss: 0.2265 - val_mean_absolute_error: 0.4187
# Epoch 89/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0166 - mean_absolute_error: 0.1049 - val_loss: 0.2314 - val_mean_absolute_error: 0.4243
# Epoch 90/1000
# 37/37 [==============================] - 0s 73us/step - loss: 0.0164 - mean_absolute_error: 0.1056 - val_loss: 0.2354 - val_mean_absolute_error: 0.4286
# Epoch 91/1000
# 37/37 [==============================] - 0s 66us/step - loss: 0.0160 - mean_absolute_error: 0.1036 - val_loss: 0.2361 - val_mean_absolute_error: 0.4292
# Epoch 92/1000
# 37/37 [==============================] - 0s 1ms/step - loss: 0.0158 - mean_absolute_error: 0.1013 - val_loss: 0.2273 - val_mean_absolute_error: 0.4193
# Epoch 93/1000
# 37/37 [==============================] - 0s 70us/step - loss: 0.0159 - mean_absolute_error: 0.1001 - val_loss: 0.2218 - val_mean_absolute_error: 0.4131
# Epoch 94/1000
# 37/37 [==============================] - 0s 68us/step - loss: 0.0157 - mean_absolute_error: 0.0995 - val_loss: 0.2346 - val_mean_absolute_error: 0.4278
# Epoch 95/1000
# 37/37 [==============================] - 0s 76us/step - loss: 0.0152 - mean_absolute_error: 0.1012 - val_loss: 0.2274 - val_mean_absolute_error: 0.4197
# Epoch 96/1000
# 37/37 [==============================] - 0s 67us/step - loss: 0.0154 - mean_absolute_error: 0.1021 - val_loss: 0.2337 - val_mean_absolute_error: 0.4267
# Epoch 97/1000
# 37/37 [==============================] - 0s 68us/step - loss: 0.0155 - mean_absolute_error: 0.1038 - val_loss: 0.2234 - val_mean_absolute_error: 0.4149
# Epoch 98/1000
# 37/37 [==============================] - 0s 59us/step - loss: 0.0146 - mean_absolute_error: 0.0995 - val_loss: 0.2286 - val_mean_absolute_error: 0.4207
# Epoch 99/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0145 - mean_absolute_error: 0.0986 - val_loss: 0.2198 - val_mean_absolute_error: 0.4105
# Epoch 100/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0145 - mean_absolute_error: 0.0972 - val_loss: 0.2291 - val_mean_absolute_error: 0.4212
# Epoch 101/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0141 - mean_absolute_error: 0.0973 - val_loss: 0.2363 - val_mean_absolute_error: 0.4293
# Epoch 102/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0142 - mean_absolute_error: 0.0964 - val_loss: 0.2402 - val_mean_absolute_error: 0.4336
# Epoch 103/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0145 - mean_absolute_error: 0.1003 - val_loss: 0.2267 - val_mean_absolute_error: 0.4185
# Epoch 104/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0138 - mean_absolute_error: 0.0975 - val_loss: 0.2241 - val_mean_absolute_error: 0.4152
# Epoch 105/1000
# 37/37 [==============================] - 0s 69us/step - loss: 0.0139 - mean_absolute_error: 0.0952 - val_loss: 0.2247 - val_mean_absolute_error: 0.4157
# Epoch 106/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0141 - mean_absolute_error: 0.0924 - val_loss: 0.2348 - val_mean_absolute_error: 0.4273
# Epoch 107/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0133 - mean_absolute_error: 0.0940 - val_loss: 0.2360 - val_mean_absolute_error: 0.4285
# Epoch 108/1000
# 37/37 [==============================] - 0s 64us/step - loss: 0.0135 - mean_absolute_error: 0.0917 - val_loss: 0.2460 - val_mean_absolute_error: 0.4394
# Epoch 109/1000
# 37/37 [==============================] - 0s 59us/step - loss: 0.0133 - mean_absolute_error: 0.0917 - val_loss: 0.2357 - val_mean_absolute_error: 0.4280
# Epoch 110/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0132 - mean_absolute_error: 0.0913 - val_loss: 0.2397 - val_mean_absolute_error: 0.4324
# Epoch 111/1000
# 37/37 [==============================] - 0s 1ms/step - loss: 0.0130 - mean_absolute_error: 0.0909 - val_loss: 0.2331 - val_mean_absolute_error: 0.4250
# Epoch 112/1000
# 37/37 [==============================] - 0s 81us/step - loss: 0.0128 - mean_absolute_error: 0.0922 - val_loss: 0.2394 - val_mean_absolute_error: 0.4318
# Epoch 113/1000
# 37/37 [==============================] - 0s 78us/step - loss: 0.0130 - mean_absolute_error: 0.0894 - val_loss: 0.2378 - val_mean_absolute_error: 0.4303
# Epoch 114/1000
# 37/37 [==============================] - 0s 74us/step - loss: 0.0125 - mean_absolute_error: 0.0913 - val_loss: 0.2481 - val_mean_absolute_error: 0.4416
# Epoch 115/1000
# 37/37 [==============================] - 0s 76us/step - loss: 0.0125 - mean_absolute_error: 0.0907 - val_loss: 0.2543 - val_mean_absolute_error: 0.4484
# Epoch 116/1000
# 37/37 [==============================] - 0s 84us/step - loss: 0.0130 - mean_absolute_error: 0.0955 - val_loss: 0.2447 - val_mean_absolute_error: 0.4376
# Epoch 117/1000
# 37/37 [==============================] - 0s 73us/step - loss: 0.0123 - mean_absolute_error: 0.0882 - val_loss: 0.2465 - val_mean_absolute_error: 0.4397
# Epoch 118/1000
# 37/37 [==============================] - 0s 78us/step - loss: 0.0122 - mean_absolute_error: 0.0895 - val_loss: 0.2451 - val_mean_absolute_error: 0.4379
# Epoch 119/1000
# 37/37 [==============================] - 0s 76us/step - loss: 0.0125 - mean_absolute_error: 0.0868 - val_loss: 0.2614 - val_mean_absolute_error: 0.4555
# Epoch 120/1000
# 37/37 [==============================] - 0s 77us/step - loss: 0.0120 - mean_absolute_error: 0.0890 - val_loss: 0.2482 - val_mean_absolute_error: 0.4414
# Epoch 121/1000
# 37/37 [==============================] - 0s 72us/step - loss: 0.0122 - mean_absolute_error: 0.0878 - val_loss: 0.2343 - val_mean_absolute_error: 0.4261
# Epoch 122/1000
# 37/37 [==============================] - 0s 73us/step - loss: 0.0126 - mean_absolute_error: 0.0870 - val_loss: 0.2423 - val_mean_absolute_error: 0.4351
# Epoch 123/1000
# 37/37 [==============================] - 0s 73us/step - loss: 0.0123 - mean_absolute_error: 0.0869 - val_loss: 0.2455 - val_mean_absolute_error: 0.4385
# Epoch 124/1000
# 37/37 [==============================] - 0s 76us/step - loss: 0.0127 - mean_absolute_error: 0.0854 - val_loss: 0.2395 - val_mean_absolute_error: 0.4321
# Epoch 125/1000
# 37/37 [==============================] - 0s 74us/step - loss: 0.0118 - mean_absolute_error: 0.0861 - val_loss: 0.2470 - val_mean_absolute_error: 0.4403
# Epoch 126/1000
# 37/37 [==============================] - 0s 81us/step - loss: 0.0115 - mean_absolute_error: 0.0869 - val_loss: 0.2506 - val_mean_absolute_error: 0.4441
# Epoch 127/1000
# 37/37 [==============================] - 0s 74us/step - loss: 0.0117 - mean_absolute_error: 0.0855 - val_loss: 0.2544 - val_mean_absolute_error: 0.4482
# Epoch 128/1000
# 37/37 [==============================] - 0s 1ms/step - loss: 0.0118 - mean_absolute_error: 0.0853 - val_loss: 0.2467 - val_mean_absolute_error: 0.4398
# Epoch 129/1000
# 37/37 [==============================] - 0s 72us/step - loss: 0.0117 - mean_absolute_error: 0.0846 - val_loss: 0.2548 - val_mean_absolute_error: 0.4488
# Epoch 130/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0115 - mean_absolute_error: 0.0887 - val_loss: 0.2551 - val_mean_absolute_error: 0.4491
# Epoch 131/1000
# 37/37 [==============================] - 0s 64us/step - loss: 0.0112 - mean_absolute_error: 0.0873 - val_loss: 0.2549 - val_mean_absolute_error: 0.4486
# Epoch 132/1000
# 37/37 [==============================] - 0s 57us/step - loss: 0.0112 - mean_absolute_error: 0.0833 - val_loss: 0.2645 - val_mean_absolute_error: 0.4589
# Epoch 133/1000
# 37/37 [==============================] - 0s 58us/step - loss: 0.0108 - mean_absolute_error: 0.0839 - val_loss: 0.2567 - val_mean_absolute_error: 0.4505
# Epoch 134/1000
# 37/37 [==============================] - 0s 55us/step - loss: 0.0109 - mean_absolute_error: 0.0830 - val_loss: 0.2650 - val_mean_absolute_error: 0.4592
# Epoch 135/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0109 - mean_absolute_error: 0.0823 - val_loss: 0.2618 - val_mean_absolute_error: 0.4561
# Epoch 136/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0110 - mean_absolute_error: 0.0851 - val_loss: 0.2611 - val_mean_absolute_error: 0.4555
# Epoch 137/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0115 - mean_absolute_error: 0.0899 - val_loss: 0.2546 - val_mean_absolute_error: 0.4484
# Epoch 138/1000
# 37/37 [==============================] - 0s 55us/step - loss: 0.0109 - mean_absolute_error: 0.0854 - val_loss: 0.2603 - val_mean_absolute_error: 0.4547
# Epoch 139/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0115 - mean_absolute_error: 0.0904 - val_loss: 0.2496 - val_mean_absolute_error: 0.4431
# Epoch 140/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0104 - mean_absolute_error: 0.0839 - val_loss: 0.2516 - val_mean_absolute_error: 0.4451
# Epoch 141/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0102 - mean_absolute_error: 0.0813 - val_loss: 0.2411 - val_mean_absolute_error: 0.4339
# Epoch 142/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0104 - mean_absolute_error: 0.0831 - val_loss: 0.2341 - val_mean_absolute_error: 0.4262
# Epoch 143/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0110 - mean_absolute_error: 0.0878 - val_loss: 0.2314 - val_mean_absolute_error: 0.4233
# Epoch 144/1000
# 37/37 [==============================] - 0s 72us/step - loss: 0.0105 - mean_absolute_error: 0.0847 - val_loss: 0.2301 - val_mean_absolute_error: 0.4217
# Epoch 145/1000
# 37/37 [==============================] - 0s 64us/step - loss: 0.0101 - mean_absolute_error: 0.0830 - val_loss: 0.2270 - val_mean_absolute_error: 0.4180
# Epoch 146/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0105 - mean_absolute_error: 0.0828 - val_loss: 0.2167 - val_mean_absolute_error: 0.4060
# Epoch 147/1000
# 37/37 [==============================] - 0s 1ms/step - loss: 0.0111 - mean_absolute_error: 0.0824 - val_loss: 0.2317 - val_mean_absolute_error: 0.4234
# Epoch 148/1000
# 37/37 [==============================] - 0s 70us/step - loss: 0.0101 - mean_absolute_error: 0.0797 - val_loss: 0.2393 - val_mean_absolute_error: 0.4321
# Epoch 149/1000
# 37/37 [==============================] - 0s 78us/step - loss: 0.0098 - mean_absolute_error: 0.0815 - val_loss: 0.2468 - val_mean_absolute_error: 0.4407
# Epoch 150/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0101 - mean_absolute_error: 0.0832 - val_loss: 0.2346 - val_mean_absolute_error: 0.4270
# Epoch 151/1000
# 37/37 [==============================] - 0s 67us/step - loss: 0.0099 - mean_absolute_error: 0.0828 - val_loss: 0.2251 - val_mean_absolute_error: 0.4161
# Epoch 152/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0097 - mean_absolute_error: 0.0794 - val_loss: 0.2294 - val_mean_absolute_error: 0.4211
# Epoch 153/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0095 - mean_absolute_error: 0.0803 - val_loss: 0.2333 - val_mean_absolute_error: 0.4255
# Epoch 154/1000
# 37/37 [==============================] - 0s 72us/step - loss: 0.0094 - mean_absolute_error: 0.0788 - val_loss: 0.2361 - val_mean_absolute_error: 0.4288
# Epoch 155/1000
# 37/37 [==============================] - 0s 70us/step - loss: 0.0096 - mean_absolute_error: 0.0809 - val_loss: 0.2304 - val_mean_absolute_error: 0.4221
# Epoch 156/1000
# 37/37 [==============================] - 0s 68us/step - loss: 0.0100 - mean_absolute_error: 0.0791 - val_loss: 0.2285 - val_mean_absolute_error: 0.4202
# Epoch 157/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0093 - mean_absolute_error: 0.0795 - val_loss: 0.2321 - val_mean_absolute_error: 0.4241
# Epoch 158/1000
# 37/37 [==============================] - 0s 58us/step - loss: 0.0095 - mean_absolute_error: 0.0789 - val_loss: 0.2319 - val_mean_absolute_error: 0.4238
# Epoch 159/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0097 - mean_absolute_error: 0.0782 - val_loss: 0.2369 - val_mean_absolute_error: 0.4299
# Epoch 160/1000
# 37/37 [==============================] - 0s 85us/step - loss: 0.0091 - mean_absolute_error: 0.0781 - val_loss: 0.2408 - val_mean_absolute_error: 0.4345
# Epoch 161/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0093 - mean_absolute_error: 0.0803 - val_loss: 0.2492 - val_mean_absolute_error: 0.4442
# Epoch 162/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0094 - mean_absolute_error: 0.0805 - val_loss: 0.2433 - val_mean_absolute_error: 0.4376
# Epoch 163/1000
# 37/37 [==============================] - 0s 67us/step - loss: 0.0091 - mean_absolute_error: 0.0793 - val_loss: 0.2465 - val_mean_absolute_error: 0.4412
# Epoch 164/1000
# 37/37 [==============================] - 0s 59us/step - loss: 0.0091 - mean_absolute_error: 0.0781 - val_loss: 0.2531 - val_mean_absolute_error: 0.4488
# Epoch 165/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0102 - mean_absolute_error: 0.0838 - val_loss: 0.2496 - val_mean_absolute_error: 0.4453
# Epoch 166/1000
# 37/37 [==============================] - 0s 1ms/step - loss: 0.0109 - mean_absolute_error: 0.0884 - val_loss: 0.2279 - val_mean_absolute_error: 0.4205
# Epoch 167/1000
# 37/37 [==============================] - 0s 57us/step - loss: 0.0097 - mean_absolute_error: 0.0831 - val_loss: 0.2320 - val_mean_absolute_error: 0.4255
# Epoch 168/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0094 - mean_absolute_error: 0.0812 - val_loss: 0.2315 - val_mean_absolute_error: 0.4249
# Epoch 169/1000
# 37/37 [==============================] - 0s 68us/step - loss: 0.0089 - mean_absolute_error: 0.0787 - val_loss: 0.2156 - val_mean_absolute_error: 0.4060
# Epoch 170/1000
# 37/37 [==============================] - 0s 70us/step - loss: 0.0087 - mean_absolute_error: 0.0772 - val_loss: 0.2171 - val_mean_absolute_error: 0.4078
# Epoch 171/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0088 - mean_absolute_error: 0.0780 - val_loss: 0.2157 - val_mean_absolute_error: 0.4059
# Epoch 172/1000
# 37/37 [==============================] - 0s 67us/step - loss: 0.0093 - mean_absolute_error: 0.0769 - val_loss: 0.2221 - val_mean_absolute_error: 0.4138
# Epoch 173/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0086 - mean_absolute_error: 0.0769 - val_loss: 0.2366 - val_mean_absolute_error: 0.4308
# Epoch 174/1000
# 37/37 [==============================] - 0s 70us/step - loss: 0.0096 - mean_absolute_error: 0.0821 - val_loss: 0.2380 - val_mean_absolute_error: 0.4325
# Epoch 175/1000
# 37/37 [==============================] - 0s 70us/step - loss: 0.0107 - mean_absolute_error: 0.0879 - val_loss: 0.2480 - val_mean_absolute_error: 0.4437
# Epoch 176/1000
# 37/37 [==============================] - 0s 68us/step - loss: 0.0100 - mean_absolute_error: 0.0840 - val_loss: 0.2307 - val_mean_absolute_error: 0.4242
# Epoch 177/1000
# 37/37 [==============================] - 0s 68us/step - loss: 0.0089 - mean_absolute_error: 0.0797 - val_loss: 0.2170 - val_mean_absolute_error: 0.4080
# Epoch 178/1000
# 37/37 [==============================] - 0s 70us/step - loss: 0.0086 - mean_absolute_error: 0.0784 - val_loss: 0.2198 - val_mean_absolute_error: 0.4115
# Epoch 179/1000
# 37/37 [==============================] - 0s 57us/step - loss: 0.0087 - mean_absolute_error: 0.0788 - val_loss: 0.2226 - val_mean_absolute_error: 0.4146
# Epoch 180/1000
# 37/37 [==============================] - 0s 66us/step - loss: 0.0083 - mean_absolute_error: 0.0749 - val_loss: 0.2300 - val_mean_absolute_error: 0.4236
# Epoch 181/1000
# 37/37 [==============================] - 0s 64us/step - loss: 0.0086 - mean_absolute_error: 0.0785 - val_loss: 0.2377 - val_mean_absolute_error: 0.4324
# Epoch 182/1000
# 37/37 [==============================] - 0s 67us/step - loss: 0.0084 - mean_absolute_error: 0.0773 - val_loss: 0.2242 - val_mean_absolute_error: 0.4169
# Epoch 183/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0081 - mean_absolute_error: 0.0758 - val_loss: 0.2327 - val_mean_absolute_error: 0.4269
# Epoch 184/1000
# 37/37 [==============================] - 0s 1ms/step - loss: 0.0081 - mean_absolute_error: 0.0753 - val_loss: 0.2258 - val_mean_absolute_error: 0.4189
# Epoch 185/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0080 - mean_absolute_error: 0.0759 - val_loss: 0.2268 - val_mean_absolute_error: 0.4201
# Epoch 186/1000
# 37/37 [==============================] - 0s 69us/step - loss: 0.0080 - mean_absolute_error: 0.0745 - val_loss: 0.2192 - val_mean_absolute_error: 0.4115
# Epoch 187/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0084 - mean_absolute_error: 0.0780 - val_loss: 0.2243 - val_mean_absolute_error: 0.4176
# Epoch 188/1000
# 37/37 [==============================] - 0s 72us/step - loss: 0.0079 - mean_absolute_error: 0.0754 - val_loss: 0.2166 - val_mean_absolute_error: 0.4083
# Epoch 189/1000
# 37/37 [==============================] - 0s 69us/step - loss: 0.0080 - mean_absolute_error: 0.0732 - val_loss: 0.2024 - val_mean_absolute_error: 0.3909
# Epoch 190/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0082 - mean_absolute_error: 0.0742 - val_loss: 0.1959 - val_mean_absolute_error: 0.3828
# Epoch 191/1000
# 37/37 [==============================] - 0s 66us/step - loss: 0.0080 - mean_absolute_error: 0.0735 - val_loss: 0.2067 - val_mean_absolute_error: 0.3967
# Epoch 192/1000
# 37/37 [==============================] - 0s 64us/step - loss: 0.0081 - mean_absolute_error: 0.0751 - val_loss: 0.2060 - val_mean_absolute_error: 0.3959
# Epoch 193/1000
# 37/37 [==============================] - 0s 56us/step - loss: 0.0082 - mean_absolute_error: 0.0771 - val_loss: 0.1999 - val_mean_absolute_error: 0.3881
# Epoch 194/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0079 - mean_absolute_error: 0.0729 - val_loss: 0.2120 - val_mean_absolute_error: 0.4032
# Epoch 195/1000
# 37/37 [==============================] - 0s 58us/step - loss: 0.0077 - mean_absolute_error: 0.0723 - val_loss: 0.2139 - val_mean_absolute_error: 0.4055
# Epoch 196/1000
# 37/37 [==============================] - 0s 56us/step - loss: 0.0078 - mean_absolute_error: 0.0712 - val_loss: 0.2137 - val_mean_absolute_error: 0.4054
# Epoch 197/1000
# 37/37 [==============================] - 0s 64us/step - loss: 0.0077 - mean_absolute_error: 0.0707 - val_loss: 0.2216 - val_mean_absolute_error: 0.4153
# Epoch 198/1000
# 37/37 [==============================] - 0s 66us/step - loss: 0.0083 - mean_absolute_error: 0.0781 - val_loss: 0.2223 - val_mean_absolute_error: 0.4163
# Epoch 199/1000
# 37/37 [==============================] - 0s 68us/step - loss: 0.0088 - mean_absolute_error: 0.0796 - val_loss: 0.2095 - val_mean_absolute_error: 0.4007
# Epoch 200/1000
# 37/37 [==============================] - 0s 59us/step - loss: 0.0079 - mean_absolute_error: 0.0752 - val_loss: 0.2147 - val_mean_absolute_error: 0.4074
# Epoch 201/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0083 - mean_absolute_error: 0.0783 - val_loss: 0.2058 - val_mean_absolute_error: 0.3964
# Epoch 202/1000
# 37/37 [==============================] - 0s 67us/step - loss: 0.0073 - mean_absolute_error: 0.0727 - val_loss: 0.2118 - val_mean_absolute_error: 0.4037
# Epoch 203/1000
# 37/37 [==============================] - 0s 1ms/step - loss: 0.0074 - mean_absolute_error: 0.0702 - val_loss: 0.2154 - val_mean_absolute_error: 0.4080
# Epoch 204/1000
# 37/37 [==============================] - 0s 58us/step - loss: 0.0078 - mean_absolute_error: 0.0706 - val_loss: 0.2125 - val_mean_absolute_error: 0.4044
# Epoch 205/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0078 - mean_absolute_error: 0.0691 - val_loss: 0.2350 - val_mean_absolute_error: 0.4313
# Epoch 206/1000
# 37/37 [==============================] - 0s 58us/step - loss: 0.0073 - mean_absolute_error: 0.0723 - val_loss: 0.2360 - val_mean_absolute_error: 0.4322
# Epoch 207/1000
# 37/37 [==============================] - 0s 58us/step - loss: 0.0073 - mean_absolute_error: 0.0701 - val_loss: 0.2139 - val_mean_absolute_error: 0.4062
# Epoch 208/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0075 - mean_absolute_error: 0.0688 - val_loss: 0.2222 - val_mean_absolute_error: 0.4164
# Epoch 209/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0070 - mean_absolute_error: 0.0702 - val_loss: 0.2181 - val_mean_absolute_error: 0.4115
# Epoch 210/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0070 - mean_absolute_error: 0.0682 - val_loss: 0.2196 - val_mean_absolute_error: 0.4135
# Epoch 211/1000
# 37/37 [==============================] - 0s 71us/step - loss: 0.0070 - mean_absolute_error: 0.0696 - val_loss: 0.2225 - val_mean_absolute_error: 0.4173
# Epoch 212/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0076 - mean_absolute_error: 0.0741 - val_loss: 0.2224 - val_mean_absolute_error: 0.4169
# Epoch 213/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0068 - mean_absolute_error: 0.0698 - val_loss: 0.2185 - val_mean_absolute_error: 0.4121
# Epoch 214/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0069 - mean_absolute_error: 0.0679 - val_loss: 0.2107 - val_mean_absolute_error: 0.4028
# Epoch 215/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0073 - mean_absolute_error: 0.0689 - val_loss: 0.2082 - val_mean_absolute_error: 0.3996
# Epoch 216/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0078 - mean_absolute_error: 0.0681 - val_loss: 0.2151 - val_mean_absolute_error: 0.4083
# Epoch 217/1000
# 37/37 [==============================] - 0s 67us/step - loss: 0.0067 - mean_absolute_error: 0.0684 - val_loss: 0.2087 - val_mean_absolute_error: 0.4003
# Epoch 218/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0072 - mean_absolute_error: 0.0667 - val_loss: 0.2111 - val_mean_absolute_error: 0.4033
# Epoch 219/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0069 - mean_absolute_error: 0.0667 - val_loss: 0.2163 - val_mean_absolute_error: 0.4098
# Epoch 220/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0068 - mean_absolute_error: 0.0660 - val_loss: 0.2195 - val_mean_absolute_error: 0.4138
# Epoch 221/1000
# 37/37 [==============================] - 0s 58us/step - loss: 0.0066 - mean_absolute_error: 0.0670 - val_loss: 0.2315 - val_mean_absolute_error: 0.4278
# Epoch 222/1000
# 37/37 [==============================] - 0s 57us/step - loss: 0.0067 - mean_absolute_error: 0.0662 - val_loss: 0.2137 - val_mean_absolute_error: 0.4068
# Epoch 223/1000
# 37/37 [==============================] - 0s 1ms/step - loss: 0.0066 - mean_absolute_error: 0.0661 - val_loss: 0.2118 - val_mean_absolute_error: 0.4045
# Epoch 224/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0064 - mean_absolute_error: 0.0656 - val_loss: 0.2099 - val_mean_absolute_error: 0.4027
# Epoch 225/1000
# 37/37 [==============================] - 0s 74us/step - loss: 0.0069 - mean_absolute_error: 0.0718 - val_loss: 0.1986 - val_mean_absolute_error: 0.3885
# Epoch 226/1000
# 37/37 [==============================] - 0s 72us/step - loss: 0.0064 - mean_absolute_error: 0.0684 - val_loss: 0.2102 - val_mean_absolute_error: 0.4031
# Epoch 227/1000
# 37/37 [==============================] - 0s 75us/step - loss: 0.0063 - mean_absolute_error: 0.0672 - val_loss: 0.2027 - val_mean_absolute_error: 0.3935
# Epoch 228/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0066 - mean_absolute_error: 0.0636 - val_loss: 0.2158 - val_mean_absolute_error: 0.4099
# Epoch 229/1000
# 37/37 [==============================] - 0s 73us/step - loss: 0.0065 - mean_absolute_error: 0.0692 - val_loss: 0.2142 - val_mean_absolute_error: 0.4081
# Epoch 230/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0063 - mean_absolute_error: 0.0685 - val_loss: 0.1929 - val_mean_absolute_error: 0.3811
# Epoch 231/1000
# 37/37 [==============================] - 0s 73us/step - loss: 0.0063 - mean_absolute_error: 0.0635 - val_loss: 0.2067 - val_mean_absolute_error: 0.3988
# Epoch 232/1000
# 37/37 [==============================] - 0s 59us/step - loss: 0.0062 - mean_absolute_error: 0.0674 - val_loss: 0.2122 - val_mean_absolute_error: 0.4056
# Epoch 233/1000
# 37/37 [==============================] - 0s 64us/step - loss: 0.0060 - mean_absolute_error: 0.0660 - val_loss: 0.2102 - val_mean_absolute_error: 0.4032
# Epoch 234/1000
# 37/37 [==============================] - 0s 71us/step - loss: 0.0061 - mean_absolute_error: 0.0643 - val_loss: 0.2074 - val_mean_absolute_error: 0.3997
# Epoch 235/1000
# 37/37 [==============================] - 0s 72us/step - loss: 0.0068 - mean_absolute_error: 0.0640 - val_loss: 0.2060 - val_mean_absolute_error: 0.3979
# Epoch 236/1000
# 37/37 [==============================] - 0s 64us/step - loss: 0.0067 - mean_absolute_error: 0.0612 - val_loss: 0.2262 - val_mean_absolute_error: 0.4226
# Epoch 237/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0060 - mean_absolute_error: 0.0639 - val_loss: 0.2137 - val_mean_absolute_error: 0.4078
# Epoch 238/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0060 - mean_absolute_error: 0.0619 - val_loss: 0.2081 - val_mean_absolute_error: 0.4008
# Epoch 239/1000
# 37/37 [==============================] - 0s 68us/step - loss: 0.0059 - mean_absolute_error: 0.0622 - val_loss: 0.2116 - val_mean_absolute_error: 0.4051
# Epoch 240/1000
# 37/37 [==============================] - 0s 56us/step - loss: 0.0059 - mean_absolute_error: 0.0625 - val_loss: 0.2030 - val_mean_absolute_error: 0.3944
# Epoch 241/1000
# 37/37 [==============================] - 0s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0620 - val_loss: 0.2129 - val_mean_absolute_error: 0.4065
# Epoch 242/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0066 - mean_absolute_error: 0.0618 - val_loss: 0.2118 - val_mean_absolute_error: 0.4053
# Epoch 243/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0063 - mean_absolute_error: 0.0619 - val_loss: 0.2087 - val_mean_absolute_error: 0.4015
# Epoch 244/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0062 - mean_absolute_error: 0.0599 - val_loss: 0.2236 - val_mean_absolute_error: 0.4199
# Epoch 245/1000
# 37/37 [==============================] - 0s 69us/step - loss: 0.0058 - mean_absolute_error: 0.0630 - val_loss: 0.2300 - val_mean_absolute_error: 0.4274
# Epoch 246/1000
# 37/37 [==============================] - 0s 64us/step - loss: 0.0061 - mean_absolute_error: 0.0625 - val_loss: 0.2340 - val_mean_absolute_error: 0.4323
# Epoch 247/1000
# 37/37 [==============================] - 0s 71us/step - loss: 0.0067 - mean_absolute_error: 0.0695 - val_loss: 0.2287 - val_mean_absolute_error: 0.4257
# Epoch 248/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0059 - mean_absolute_error: 0.0603 - val_loss: 0.2228 - val_mean_absolute_error: 0.4187
# Epoch 249/1000
# 37/37 [==============================] - 0s 64us/step - loss: 0.0059 - mean_absolute_error: 0.0596 - val_loss: 0.2081 - val_mean_absolute_error: 0.4011
# Epoch 250/1000
# 37/37 [==============================] - 0s 59us/step - loss: 0.0056 - mean_absolute_error: 0.0619 - val_loss: 0.1923 - val_mean_absolute_error: 0.3809
# Epoch 251/1000
# 37/37 [==============================] - 0s 75us/step - loss: 0.0057 - mean_absolute_error: 0.0593 - val_loss: 0.1900 - val_mean_absolute_error: 0.3783
# Epoch 252/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0058 - mean_absolute_error: 0.0642 - val_loss: 0.1985 - val_mean_absolute_error: 0.3893
# Epoch 253/1000
# 37/37 [==============================] - 0s 69us/step - loss: 0.0056 - mean_absolute_error: 0.0638 - val_loss: 0.1837 - val_mean_absolute_error: 0.3696
# Epoch 254/1000
# 37/37 [==============================] - 0s 72us/step - loss: 0.0060 - mean_absolute_error: 0.0599 - val_loss: 0.1925 - val_mean_absolute_error: 0.3815
# Epoch 255/1000
# 37/37 [==============================] - 0s 69us/step - loss: 0.0057 - mean_absolute_error: 0.0608 - val_loss: 0.1920 - val_mean_absolute_error: 0.3806
# Epoch 256/1000
# 37/37 [==============================] - 0s 69us/step - loss: 0.0064 - mean_absolute_error: 0.0590 - val_loss: 0.2018 - val_mean_absolute_error: 0.3936
# Epoch 257/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0057 - mean_absolute_error: 0.0585 - val_loss: 0.1973 - val_mean_absolute_error: 0.3879
# Epoch 258/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0060 - mean_absolute_error: 0.0578 - val_loss: 0.2097 - val_mean_absolute_error: 0.4036
# Epoch 259/1000
# 37/37 [==============================] - 0s 66us/step - loss: 0.0055 - mean_absolute_error: 0.0579 - val_loss: 0.1953 - val_mean_absolute_error: 0.3854
# Epoch 260/1000
# 37/37 [==============================] - 0s 64us/step - loss: 0.0054 - mean_absolute_error: 0.0582 - val_loss: 0.1850 - val_mean_absolute_error: 0.3721
# Epoch 261/1000
# 37/37 [==============================] - 0s 1ms/step - loss: 0.0053 - mean_absolute_error: 0.0592 - val_loss: 0.1793 - val_mean_absolute_error: 0.3643
# Epoch 262/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0054 - mean_absolute_error: 0.0585 - val_loss: 0.1911 - val_mean_absolute_error: 0.3804
# Epoch 263/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0052 - mean_absolute_error: 0.0597 - val_loss: 0.1809 - val_mean_absolute_error: 0.3666
# Epoch 264/1000
# 37/37 [==============================] - 0s 64us/step - loss: 0.0057 - mean_absolute_error: 0.0576 - val_loss: 0.1898 - val_mean_absolute_error: 0.3789
# Epoch 265/1000
# 37/37 [==============================] - 0s 68us/step - loss: 0.0051 - mean_absolute_error: 0.0598 - val_loss: 0.1967 - val_mean_absolute_error: 0.3880
# Epoch 266/1000
# 37/37 [==============================] - 0s 67us/step - loss: 0.0052 - mean_absolute_error: 0.0587 - val_loss: 0.1938 - val_mean_absolute_error: 0.3840
# Epoch 267/1000
# 37/37 [==============================] - 0s 68us/step - loss: 0.0061 - mean_absolute_error: 0.0577 - val_loss: 0.1834 - val_mean_absolute_error: 0.3704
# Epoch 268/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0056 - mean_absolute_error: 0.0569 - val_loss: 0.1890 - val_mean_absolute_error: 0.3780
# Epoch 269/1000
# 37/37 [==============================] - 0s 57us/step - loss: 0.0052 - mean_absolute_error: 0.0573 - val_loss: 0.1780 - val_mean_absolute_error: 0.3631
# Epoch 270/1000
# 37/37 [==============================] - 0s 67us/step - loss: 0.0056 - mean_absolute_error: 0.0572 - val_loss: 0.1740 - val_mean_absolute_error: 0.3577
# Epoch 271/1000
# 37/37 [==============================] - 0s 66us/step - loss: 0.0054 - mean_absolute_error: 0.0560 - val_loss: 0.1877 - val_mean_absolute_error: 0.3767
# Epoch 272/1000
# 37/37 [==============================] - 0s 72us/step - loss: 0.0051 - mean_absolute_error: 0.0612 - val_loss: 0.1884 - val_mean_absolute_error: 0.3774
# Epoch 273/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0052 - mean_absolute_error: 0.0547 - val_loss: 0.1941 - val_mean_absolute_error: 0.3850
# Epoch 274/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0049 - mean_absolute_error: 0.0574 - val_loss: 0.1928 - val_mean_absolute_error: 0.3833
# Epoch 275/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0053 - mean_absolute_error: 0.0542 - val_loss: 0.2002 - val_mean_absolute_error: 0.3931
# Epoch 276/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0049 - mean_absolute_error: 0.0589 - val_loss: 0.1787 - val_mean_absolute_error: 0.3646
# Epoch 277/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0051 - mean_absolute_error: 0.0545 - val_loss: 0.1853 - val_mean_absolute_error: 0.3738
# Epoch 278/1000
# 37/37 [==============================] - 0s 64us/step - loss: 0.0050 - mean_absolute_error: 0.0590 - val_loss: 0.1910 - val_mean_absolute_error: 0.3815
# Epoch 279/1000
# 37/37 [==============================] - 0s 66us/step - loss: 0.0057 - mean_absolute_error: 0.0647 - val_loss: 0.1892 - val_mean_absolute_error: 0.3790
# Epoch 280/1000
# 37/37 [==============================] - 0s 1ms/step - loss: 0.0048 - mean_absolute_error: 0.0589 - val_loss: 0.1994 - val_mean_absolute_error: 0.3921
# Epoch 281/1000
# 37/37 [==============================] - 0s 64us/step - loss: 0.0047 - mean_absolute_error: 0.0579 - val_loss: 0.1940 - val_mean_absolute_error: 0.3849
# Epoch 282/1000
# 37/37 [==============================] - 0s 66us/step - loss: 0.0051 - mean_absolute_error: 0.0532 - val_loss: 0.1971 - val_mean_absolute_error: 0.3893
# Epoch 283/1000
# 37/37 [==============================] - 0s 72us/step - loss: 0.0047 - mean_absolute_error: 0.0554 - val_loss: 0.1954 - val_mean_absolute_error: 0.3870
# Epoch 284/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0046 - mean_absolute_error: 0.0559 - val_loss: 0.2057 - val_mean_absolute_error: 0.4001
# Epoch 285/1000
# ...
# Epoch 906/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0022 - mean_absolute_error: 0.0383 - val_loss: 0.1346 - val_mean_absolute_error: 0.3147
# Epoch 907/1000
# 37/37 [==============================] - 0s 73us/step - loss: 0.0021 - mean_absolute_error: 0.0372 - val_loss: 0.1340 - val_mean_absolute_error: 0.3138
# Epoch 908/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0021 - mean_absolute_error: 0.0364 - val_loss: 0.1188 - val_mean_absolute_error: 0.2889
# Epoch 909/1000
# 37/37 [==============================] - 0s 67us/step - loss: 0.0020 - mean_absolute_error: 0.0353 - val_loss: 0.1339 - val_mean_absolute_error: 0.3139
# Epoch 910/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0029 - mean_absolute_error: 0.0463 - val_loss: 0.1272 - val_mean_absolute_error: 0.3032
# Epoch 911/1000
# 37/37 [==============================] - 0s 69us/step - loss: 0.0028 - mean_absolute_error: 0.0442 - val_loss: 0.1314 - val_mean_absolute_error: 0.3098
# Epoch 912/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0019 - mean_absolute_error: 0.0352 - val_loss: 0.1410 - val_mean_absolute_error: 0.3248
# Epoch 913/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0020 - mean_absolute_error: 0.0362 - val_loss: 0.1265 - val_mean_absolute_error: 0.3015
# Epoch 914/1000
# 37/37 [==============================] - 0s 67us/step - loss: 0.0023 - mean_absolute_error: 0.0383 - val_loss: 0.1422 - val_mean_absolute_error: 0.3262
# Epoch 915/1000
# 37/37 [==============================] - 0s 66us/step - loss: 0.0020 - mean_absolute_error: 0.0353 - val_loss: 0.1420 - val_mean_absolute_error: 0.3262
# Epoch 916/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0026 - mean_absolute_error: 0.0438 - val_loss: 0.1330 - val_mean_absolute_error: 0.3120
# Epoch 917/1000
# 37/37 [==============================] - 0s 69us/step - loss: 0.0019 - mean_absolute_error: 0.0354 - val_loss: 0.1340 - val_mean_absolute_error: 0.3139
# Epoch 918/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0024 - mean_absolute_error: 0.0396 - val_loss: 0.1315 - val_mean_absolute_error: 0.3096
# Epoch 919/1000
# 37/37 [==============================] - 0s 64us/step - loss: 0.0019 - mean_absolute_error: 0.0355 - val_loss: 0.1269 - val_mean_absolute_error: 0.3021
# Epoch 920/1000
# 37/37 [==============================] - 0s 73us/step - loss: 0.0021 - mean_absolute_error: 0.0368 - val_loss: 0.1314 - val_mean_absolute_error: 0.3095
# Epoch 921/1000
# 37/37 [==============================] - 0s 86us/step - loss: 0.0019 - mean_absolute_error: 0.0352 - val_loss: 0.1434 - val_mean_absolute_error: 0.3281
# Epoch 922/1000
# 37/37 [==============================] - 0s 77us/step - loss: 0.0022 - mean_absolute_error: 0.0373 - val_loss: 0.1553 - val_mean_absolute_error: 0.3454
# Epoch 923/1000
# 37/37 [==============================] - 0s 1ms/step - loss: 0.0022 - mean_absolute_error: 0.0390 - val_loss: 0.1502 - val_mean_absolute_error: 0.3379
# Epoch 924/1000
# 37/37 [==============================] - 0s 67us/step - loss: 0.0020 - mean_absolute_error: 0.0360 - val_loss: 0.1399 - val_mean_absolute_error: 0.3226
# Epoch 925/1000
# 37/37 [==============================] - 0s 58us/step - loss: 0.0019 - mean_absolute_error: 0.0349 - val_loss: 0.1394 - val_mean_absolute_error: 0.3217
# Epoch 926/1000
# 37/37 [==============================] - 0s 56us/step - loss: 0.0022 - mean_absolute_error: 0.0383 - val_loss: 0.1241 - val_mean_absolute_error: 0.2971
# Epoch 927/1000
# 37/37 [==============================] - 0s 64us/step - loss: 0.0027 - mean_absolute_error: 0.0425 - val_loss: 0.1385 - val_mean_absolute_error: 0.3202
# Epoch 928/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0020 - mean_absolute_error: 0.0350 - val_loss: 0.1459 - val_mean_absolute_error: 0.3315
# Epoch 929/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0023 - mean_absolute_error: 0.0392 - val_loss: 0.1483 - val_mean_absolute_error: 0.3351
# Epoch 930/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0024 - mean_absolute_error: 0.0397 - val_loss: 0.1416 - val_mean_absolute_error: 0.3251
# Epoch 931/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0021 - mean_absolute_error: 0.0375 - val_loss: 0.1235 - val_mean_absolute_error: 0.2960
# Epoch 932/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0021 - mean_absolute_error: 0.0361 - val_loss: 0.1234 - val_mean_absolute_error: 0.2958
# Epoch 933/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0021 - mean_absolute_error: 0.0357 - val_loss: 0.1143 - val_mean_absolute_error: 0.2802
# Epoch 934/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0023 - mean_absolute_error: 0.0367 - val_loss: 0.1238 - val_mean_absolute_error: 0.2969
# Epoch 935/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0027 - mean_absolute_error: 0.0449 - val_loss: 0.1335 - val_mean_absolute_error: 0.3123
# Epoch 936/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0023 - mean_absolute_error: 0.0384 - val_loss: 0.1421 - val_mean_absolute_error: 0.3258
# Epoch 937/1000
# 37/37 [==============================] - 0s 70us/step - loss: 0.0019 - mean_absolute_error: 0.0350 - val_loss: 0.1491 - val_mean_absolute_error: 0.3362
# Epoch 938/1000
# 37/37 [==============================] - 0s 59us/step - loss: 0.0020 - mean_absolute_error: 0.0357 - val_loss: 0.1296 - val_mean_absolute_error: 0.3061
# Epoch 939/1000
# 37/37 [==============================] - 0s 66us/step - loss: 0.0020 - mean_absolute_error: 0.0363 - val_loss: 0.1277 - val_mean_absolute_error: 0.3029
# Epoch 940/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0020 - mean_absolute_error: 0.0350 - val_loss: 0.1274 - val_mean_absolute_error: 0.3024
# Epoch 941/1000
# 37/37 [==============================] - 0s 81us/step - loss: 0.0025 - mean_absolute_error: 0.0412 - val_loss: 0.1442 - val_mean_absolute_error: 0.3290
# Epoch 942/1000
# 37/37 [==============================] - 0s 1ms/step - loss: 0.0020 - mean_absolute_error: 0.0366 - val_loss: 0.1325 - val_mean_absolute_error: 0.3107
# Epoch 943/1000
# 37/37 [==============================] - 0s 66us/step - loss: 0.0019 - mean_absolute_error: 0.0355 - val_loss: 0.1436 - val_mean_absolute_error: 0.3278
# Epoch 944/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0020 - mean_absolute_error: 0.0364 - val_loss: 0.1453 - val_mean_absolute_error: 0.3306
# Epoch 945/1000
# 37/37 [==============================] - 0s 71us/step - loss: 0.0031 - mean_absolute_error: 0.0474 - val_loss: 0.1418 - val_mean_absolute_error: 0.3248
# Epoch 946/1000
# 37/37 [==============================] - 0s 58us/step - loss: 0.0020 - mean_absolute_error: 0.0353 - val_loss: 0.1579 - val_mean_absolute_error: 0.3485
# Epoch 947/1000
# 37/37 [==============================] - 0s 64us/step - loss: 0.0021 - mean_absolute_error: 0.0360 - val_loss: 0.1623 - val_mean_absolute_error: 0.3547
# Epoch 948/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0022 - mean_absolute_error: 0.0370 - val_loss: 0.1614 - val_mean_absolute_error: 0.3537
# Epoch 949/1000
# 37/37 [==============================] - 0s 56us/step - loss: 0.0033 - mean_absolute_error: 0.0496 - val_loss: 0.1449 - val_mean_absolute_error: 0.3294
# Epoch 950/1000
# 37/37 [==============================] - 0s 74us/step - loss: 0.0020 - mean_absolute_error: 0.0343 - val_loss: 0.1493 - val_mean_absolute_error: 0.3364
# Epoch 951/1000
# 37/37 [==============================] - 0s 68us/step - loss: 0.0024 - mean_absolute_error: 0.0395 - val_loss: 0.1590 - val_mean_absolute_error: 0.3502
# Epoch 952/1000
# 37/37 [==============================] - 0s 67us/step - loss: 0.0022 - mean_absolute_error: 0.0374 - val_loss: 0.1364 - val_mean_absolute_error: 0.3167
# Epoch 953/1000
# 37/37 [==============================] - 0s 71us/step - loss: 0.0019 - mean_absolute_error: 0.0344 - val_loss: 0.1362 - val_mean_absolute_error: 0.3167
# Epoch 954/1000
# 37/37 [==============================] - 0s 57us/step - loss: 0.0025 - mean_absolute_error: 0.0416 - val_loss: 0.1421 - val_mean_absolute_error: 0.3256
# Epoch 955/1000
# 37/37 [==============================] - 0s 67us/step - loss: 0.0020 - mean_absolute_error: 0.0356 - val_loss: 0.1397 - val_mean_absolute_error: 0.3217
# Epoch 956/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0021 - mean_absolute_error: 0.0371 - val_loss: 0.1434 - val_mean_absolute_error: 0.3274
# Epoch 957/1000
# 37/37 [==============================] - 0s 59us/step - loss: 0.0021 - mean_absolute_error: 0.0371 - val_loss: 0.1392 - val_mean_absolute_error: 0.3208
# Epoch 958/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0026 - mean_absolute_error: 0.0429 - val_loss: 0.1421 - val_mean_absolute_error: 0.3253
# Epoch 959/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0021 - mean_absolute_error: 0.0370 - val_loss: 0.1394 - val_mean_absolute_error: 0.3214
# Epoch 960/1000
# 37/37 [==============================] - 0s 70us/step - loss: 0.0020 - mean_absolute_error: 0.0364 - val_loss: 0.1486 - val_mean_absolute_error: 0.3352
# Epoch 961/1000
# 37/37 [==============================] - 0s 1ms/step - loss: 0.0020 - mean_absolute_error: 0.0351 - val_loss: 0.1546 - val_mean_absolute_error: 0.3435
# Epoch 962/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0021 - mean_absolute_error: 0.0361 - val_loss: 0.1728 - val_mean_absolute_error: 0.3691
# Epoch 963/1000
# 37/37 [==============================] - 0s 68us/step - loss: 0.0034 - mean_absolute_error: 0.0497 - val_loss: 0.1474 - val_mean_absolute_error: 0.3333
# Epoch 964/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0020 - mean_absolute_error: 0.0352 - val_loss: 0.1609 - val_mean_absolute_error: 0.3528
# Epoch 965/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0021 - mean_absolute_error: 0.0368 - val_loss: 0.1412 - val_mean_absolute_error: 0.3239
# Epoch 966/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0031 - mean_absolute_error: 0.0451 - val_loss: 0.1429 - val_mean_absolute_error: 0.3266
# Epoch 967/1000
# 37/37 [==============================] - 0s 69us/step - loss: 0.0020 - mean_absolute_error: 0.0364 - val_loss: 0.1372 - val_mean_absolute_error: 0.3178
# Epoch 968/1000
# 37/37 [==============================] - 0s 66us/step - loss: 0.0019 - mean_absolute_error: 0.0345 - val_loss: 0.1453 - val_mean_absolute_error: 0.3301
# Epoch 969/1000
# 37/37 [==============================] - 0s 62us/step - loss: 0.0020 - mean_absolute_error: 0.0360 - val_loss: 0.1322 - val_mean_absolute_error: 0.3099
# Epoch 970/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0020 - mean_absolute_error: 0.0358 - val_loss: 0.1406 - val_mean_absolute_error: 0.3230
# Epoch 971/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0020 - mean_absolute_error: 0.0351 - val_loss: 0.1514 - val_mean_absolute_error: 0.3393
# Epoch 972/1000
# 37/37 [==============================] - 0s 59us/step - loss: 0.0024 - mean_absolute_error: 0.0408 - val_loss: 0.1365 - val_mean_absolute_error: 0.3171
# Epoch 973/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0021 - mean_absolute_error: 0.0374 - val_loss: 0.1346 - val_mean_absolute_error: 0.3139
# Epoch 974/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0019 - mean_absolute_error: 0.0349 - val_loss: 0.1334 - val_mean_absolute_error: 0.3122
# Epoch 975/1000
# 37/37 [==============================] - 0s 63us/step - loss: 0.0020 - mean_absolute_error: 0.0358 - val_loss: 0.1239 - val_mean_absolute_error: 0.2962
# Epoch 976/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0031 - mean_absolute_error: 0.0461 - val_loss: 0.1345 - val_mean_absolute_error: 0.3138
# Epoch 977/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0019 - mean_absolute_error: 0.0354 - val_loss: 0.1435 - val_mean_absolute_error: 0.3277
# Epoch 978/1000
# 37/37 [==============================] - 0s 73us/step - loss: 0.0019 - mean_absolute_error: 0.0353 - val_loss: 0.1432 - val_mean_absolute_error: 0.3276
# Epoch 979/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0026 - mean_absolute_error: 0.0428 - val_loss: 0.1441 - val_mean_absolute_error: 0.3284
# Epoch 980/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0020 - mean_absolute_error: 0.0366 - val_loss: 0.1326 - val_mean_absolute_error: 0.3108
# Epoch 981/1000
# 37/37 [==============================] - 0s 1ms/step - loss: 0.0019 - mean_absolute_error: 0.0357 - val_loss: 0.1493 - val_mean_absolute_error: 0.3366
# Epoch 982/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0024 - mean_absolute_error: 0.0401 - val_loss: 0.1289 - val_mean_absolute_error: 0.3050
# Epoch 983/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0019 - mean_absolute_error: 0.0353 - val_loss: 0.1290 - val_mean_absolute_error: 0.3048
# Epoch 984/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0022 - mean_absolute_error: 0.0367 - val_loss: 0.1259 - val_mean_absolute_error: 0.2997
# Epoch 985/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0020 - mean_absolute_error: 0.0351 - val_loss: 0.1448 - val_mean_absolute_error: 0.3296
# Epoch 986/1000
# 37/37 [==============================] - 0s 71us/step - loss: 0.0019 - mean_absolute_error: 0.0350 - val_loss: 0.1290 - val_mean_absolute_error: 0.3049
# Epoch 987/1000
# 37/37 [==============================] - 0s 66us/step - loss: 0.0020 - mean_absolute_error: 0.0345 - val_loss: 0.1326 - val_mean_absolute_error: 0.3109
# Epoch 988/1000
# 37/37 [==============================] - 0s 65us/step - loss: 0.0019 - mean_absolute_error: 0.0347 - val_loss: 0.1362 - val_mean_absolute_error: 0.3164
# Epoch 989/1000
# 37/37 [==============================] - 0s 67us/step - loss: 0.0025 - mean_absolute_error: 0.0414 - val_loss: 0.1331 - val_mean_absolute_error: 0.3115
# Epoch 990/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0021 - mean_absolute_error: 0.0361 - val_loss: 0.1500 - val_mean_absolute_error: 0.3372
# Epoch 991/1000
# 37/37 [==============================] - 0s 66us/step - loss: 0.0021 - mean_absolute_error: 0.0365 - val_loss: 0.1567 - val_mean_absolute_error: 0.3469
# Epoch 992/1000
# 37/37 [==============================] - 0s 57us/step - loss: 0.0020 - mean_absolute_error: 0.0358 - val_loss: 0.1502 - val_mean_absolute_error: 0.3375
# Epoch 993/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0021 - mean_absolute_error: 0.0360 - val_loss: 0.1402 - val_mean_absolute_error: 0.3225
# Epoch 994/1000
# 37/37 [==============================] - 0s 61us/step - loss: 0.0019 - mean_absolute_error: 0.0344 - val_loss: 0.1381 - val_mean_absolute_error: 0.3190
# Epoch 995/1000
# 37/37 [==============================] - 0s 57us/step - loss: 0.0021 - mean_absolute_error: 0.0369 - val_loss: 0.1536 - val_mean_absolute_error: 0.3423
# Epoch 996/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0020 - mean_absolute_error: 0.0351 - val_loss: 0.1577 - val_mean_absolute_error: 0.3484
# Epoch 997/1000
# 37/37 [==============================] - 0s 70us/step - loss: 0.0020 - mean_absolute_error: 0.0363 - val_loss: 0.1443 - val_mean_absolute_error: 0.3287
# Epoch 998/1000
# 37/37 [==============================] - 0s 71us/step - loss: 0.0023 - mean_absolute_error: 0.0394 - val_loss: 0.1399 - val_mean_absolute_error: 0.3218
# Epoch 999/1000
# 37/37 [==============================] - 0s 60us/step - loss: 0.0019 - mean_absolute_error: 0.0341 - val_loss: 0.1461 - val_mean_absolute_error: 0.3310
# Epoch 1000/1000
# 37/37 [==============================] - 0s 57us/step - loss: 0.0020 - mean_absolute_error: 0.0354 - val_loss: 0.1409 - val_mean_absolute_error: 0.3233

# %%
model.evaluate(test_t1, np.array(y_test).reshape(1,len(y_test))[0])
pred_values=model.predict(test_t1)
pred_values.reshape(1,len(pred_values))[0]
# Out:
# 12/12 [==============================] - 0s 45us/step
# array([0.4523257 , 0.47461414, 0.49690259, 0.51784724, 0.5385759 ,
#        0.5593046 , 0.5800333 , 0.60101813, 0.6225417 , 0.6440654 ,
#        0.66558903, 0.68711257], dtype=float32)

# %%
plt.scatter(test_t1,pred_values)
plt.plot(test_t1,y_test,'r')
# Out:
# <img src="https://cdn.kesci.com/upload/rt/1A4CEDB28A5F41238D832CD166C4C730/rbnblmj3dq.png">
