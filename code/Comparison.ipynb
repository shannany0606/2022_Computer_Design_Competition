# %%
import pandas as pd
from pylab import rcParams
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
from sklearn.metrics import roc_auc_score
from sklearn import metrics 
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures
import statsmodels.formula.api as sm
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler,PowerTransformer,PolynomialFeatures
from sklearn.linear_model import LinearRegression
import operator
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from pandas import DataFrame
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# #  GDP比较

# %%
barWidth = 0.15
fig = plt.subplots(figsize =(12, 8)) 
IT = [235.799, 163.584, 166.957]
ECE=[218.977, 128.621,156.737]
br1 = np.arange(3) 
br2 = [x + barWidth for x in br1] 
plt.bar(br1, IT, color ='b', width = barWidth, 
        edgecolor ='grey', label ='IT') 
plt.bar(br2, ECE, color ='g', width = barWidth, 
        edgecolor ='grey', label ='ECE')  
plt.xlabel('Countries', fontweight ='bold') 
plt.ylabel('GDP', fontweight ='bold') 
plt.xticks([r + barWidth for r in range(len(IT))], 
           ['USA', 'IND', 'ZAF']) 
plt.legend(labels=['Predicted data', 'Actual data'])
plt.show()
# Out:
# <img src="https://cdn.kesci.com/upload/rt/C12EE2ACFAF24071A5C422AD024A1DC1/rbnky9x1kv.png">

# %% [markdown]
# # 失业率比较

# %%
barWidth = 0.15
fig = plt.subplots(figsize =(12, 8)) 
IT = [4.013,5.127,26.020]
ECE=[12.921, 6.164,34.005]
br1 = np.arange(3) 
br2 = [x + barWidth for x in br1] 
   
# Make the plot 
plt.bar(br1, IT, color ='b', width = barWidth, 
        edgecolor ='grey', label ='IT') 
plt.bar(br2, ECE, color ='g', width = barWidth, 
        edgecolor ='grey', label ='ECE')  
# Adding Xticks  
plt.xlabel('Countries', fontweight ='bold') 
plt.ylabel('Unemplyment rate(%)', fontweight ='bold') 
plt.xticks([r + barWidth for r in range(len(IT))], 
           ['USA', 'RUS', 'ZAF']) 
plt.legend(labels=['Predicted data', 'Actual data'])
plt.show()
# Out:
# <img src="https://cdn.kesci.com/upload/rt/E803F4B745454C4AAA40F6E31D6C9200/rbnm328wci.png">

# %% [markdown]
# # 劳动力成本比较

# %%
barWidth = 0.15
fig = plt.subplots(figsize =(12, 8)) 
IT = [106.391,125.844,114.881]
ECE=[110.1, 127.35,135.55]
br1 = np.arange(3) 
br2 = [x + barWidth for x in br1] 
   
# Make the plot 
plt.bar(br1, IT, color ='b', width = barWidth, 
        edgecolor ='grey', label ='IT') 
plt.bar(br2, ECE, color ='g', width = barWidth, 
        edgecolor ='grey', label ='ECE')  
# Adding Xticks  
plt.xlabel('Countries', fontweight ='bold') 
plt.ylabel('labour cost', fontweight ='bold') 
plt.xticks([r + barWidth for r in range(len(IT))], 
           ['AUS', 'CZE', 'LTU']) 
plt.legend(labels=['Predicted data', 'Actual data'])
plt.show()
# Out:
# <img src="https://cdn.kesci.com/upload/rt/8B0305A7735744D8899DB645747B30D2/rbnnfhis4a.png">

# %% [markdown]
# # 国际贸易额比较

# %%
barWidth = 0.15
fig = plt.subplots(figsize =(12, 8)) 
IT = [257.433,241.953,89.968]
ECE=[240.84, 251.07,75.77]
br1 = np.arange(3) 
br2 = [x + barWidth for x in br1] 
   
# Make the plot 
plt.bar(br1, IT, color ='b', width = barWidth, 
        edgecolor ='grey', label ='IT') 
plt.bar(br2, ECE, color ='g', width = barWidth, 
        edgecolor ='grey', label ='ECE')  
# Adding Xticks  
plt.xlabel('Countries', fontweight ='bold') 
plt.ylabel('labour cost', fontweight ='bold') 
plt.xticks([r + barWidth for r in range(len(IT))], 
           ['AUS', 'IND', 'ZAF']) 
plt.legend(labels=['Predicted data', 'Actual data'])
plt.show()
# Out:
# <img src="https://cdn.kesci.com/upload/rt/29091E5C6FD5424EB7DA190311A12B28/rbnqa8va7n.png">
