# %%
import pandas as pd
from pylab import rcParams
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
from sklearn.metrics import roc_auc_score
from sklearn import metrics 
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures
import statsmodels.formula.api as sm
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler,PowerTransformer,PolynomialFeatures
from sklearn.linear_model import LinearRegression
import operator
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # *劳动力成本回归模型（澳大利亚）*

# %%
df=pd.read_csv("/home/mw/input/Labor_data4880/labour_cost.csv")
df=df[['LOCATION', 'TIME', 'Value','Measure']]
t1=df[df['Measure']=='Index']
df=t1[t1['LOCATION']=='AUS']
plt.plot(df['TIME'],df['Value'])
plt.title('Labor cost-Australia')
plt.xlabel('Year') 
plt.ylabel('Labor Cost')
# Out:
# Text(0, 0.5, 'Labor Cost')
# <img src="https://cdn.kesci.com/upload/rt/1C45031390AA403F8269AFEA92C77178/rbnij2ddr4.png">

# %% [markdown]
# # 线性回归模型

# %%
x=[i for i in df['TIME']]
y=[i for i in df['Value']]
x_array=x
y_array=y
x_shape=np.array(df['TIME'][:-1]).reshape(-1, 1)
y_shape=np.array(df['Value'][:-1]).reshape(-1, 1)
model=LinearRegression()
model.fit(x_shape,y_shape)
x_test=np.linspace(1975,2020)
y_pred=model.predict(x_test[:,None])
plt.plot(x_shape,y_shape,'b')
plt.plot(x_test,y_pred,'r')
plt.title('Labor cost-Australia')
plt.legend(['Actual data','Predicted data'])
plt.xlabel('Year') 
plt.ylabel('Labor Cost')
plt.show()
# Out:
# <img src="https://cdn.kesci.com/upload/rt/8C27CFBCC34F4834A9977AB111E9AFBE/rbnij83zfx.png">

# %%
x=np.asarray(x)
y=np.asarray(y)
x = x[:, np.newaxis]
y = y[:, np.newaxis]
l=int(len(x)*.7)
x_train,x_test=x[:l],x[l:]
y_train,y_test=y[:l],y[l:]
y_train=y_train.reshape(len(y_train),1)
x_train=x_train.reshape(len(x_train),1)
x_test=x_test.reshape(len(x_test),1)
y_test=y_test.reshape(len(y_test),1)
model = linear_model.LinearRegression()
model.fit(x_train,y_train)
y_poly_pred=model.predict(x_test.reshape(-1, 1))
rmse = np.sqrt(mean_squared_error(y_poly_pred,y_test))
r2 = r2_score(y_test,y_poly_pred)
r2 = r2_score(y_test,y_poly_pred)
print("RMSE=",rmse)
print("R方=",r2)
# Out:
# RMSE= 3.797124608720174
# R方= 0.5759020532208714

# %%
x=x.reshape(len(x),1)
y=y.reshape(len(y),1)

# %%
model.predict(np.asarray([2020]).reshape(1, -1))
# Out:
# array([[106.39097505]])

# %% [markdown]
# **2020澳大利亚劳动力成本预测值**

# %% [markdown]
# # *劳动力成本回归模型（捷克）*

# %%
df=pd.read_csv("/home/mw/input/Labor_data4880/labour_cost.csv")
t1=df[df['Measure']=='Index']
df=t1[t1['LOCATION']=='CZE']

# %%
plt.plot(df['TIME'],df['Value'])
plt.title('Labor cost-Czech')
plt.xlabel('Year') 
plt.ylabel('Labor Cost')
# Out:
# Text(0, 0.5, 'Labor Cost')
# <img src="https://cdn.kesci.com/upload/rt/5730F03A72414D97ADF8BF16EF162C3B/rbnijjquyy.png">

# %% [markdown]
# # 线性回归模型

# %%
df=df[['TIME','Value']]
x=[i for i in df['TIME']]
y=[i for i in df['Value']]
x_array=x
y_array=y
x_shape=np.array(df['TIME'][:-1]).reshape(-1, 1)
y_shape=np.array(df['Value'][:-1]).reshape(-1, 1)
model=LinearRegression()
model.fit(x_shape,y_shape)
x_test=np.linspace(1995,2020)
y_pred=model.predict(x_test[:,None])
plt.plot(x_shape,y_shape,'b')
plt.plot(x_test,y_pred,'r')
plt.legend(['Actual data','Predicted data'])
plt.title('Labor cost-Czech')
plt.xlabel('Year') 
plt.ylabel('Labor Cost')
plt.show()
x=np.asarray(x)
y=np.asarray(y)
x = x[:, np.newaxis]
y = y[:, np.newaxis]
l=int(len(x)*.7)
x_train,x_test=x[:l],x[l:]
y_train,y_test=y[:l],y[l:]
model = linear_model.LinearRegression()
model.fit(x_train,y_train)
y_poly_pred=model.predict(x_test.reshape(-1, 1))
rmse = np.sqrt(mean_squared_error(y_poly_pred,y_test))
r2 = r2_score(y_test,y_poly_pred)
r2 = r2_score(y_test,y_poly_pred)
print("RMSE=",rmse)
print("R方=",r2)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/9FD0EC4025A7468B81CF524E1F9B4640/rbnijn6miq.png">
# RMSE= 7.920517844405943
# R方= -0.4815091480944065

# %% [markdown]
# # 二阶多项式回归模型

# %%
polynomial_features= PolynomialFeatures(degree=2)
x_poly = polynomial_features.fit_transform(x)
model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)
rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.title('Labor cost-Czech')
plt.xlabel('Year') 
plt.ylabel('Labor Cost')
plt.legend(['Predicted data','Actual data'])
plt.show()
# Out:
# <img src="https://cdn.kesci.com/upload/rt/7F7B938DCAC1436A9D0DBE4493472208/rbnijsh233.png">

# %% [markdown]
# # 三阶多项式回归模型

# %%
polynomial_features= PolynomialFeatures(degree=3)
x_poly = polynomial_features.fit_transform(x)
model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)
rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
plt.plot(x, y)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.title('labour cost-Czech')
plt.legend(['Actual data','Predicted data'])
plt.xlabel('Year') 
plt.ylabel('Labor Cost')
plt.show()
polynomial_features= PolynomialFeatures(degree=3)
x_poly = polynomial_features.fit_transform(x_train)
model = LinearRegression()
model.fit(x_poly, y_train)
x_test_poly=polynomial_features.fit_transform(x_test)
y_poly_pred = model.predict(x_test_poly)
rmse = np.sqrt(mean_squared_error(y_poly_pred,y_test))
r2 = r2_score(y_test,y_poly_pred)
print("RMSE=",rmse)
print("R方=",r2)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/D356EF4F983E40DFA66261A302FF5E0C/rbnik2dpmw.png">
# RMSE= 4.098435290446573
# R方= 0.6033263531045151

# %%
model.predict(polynomial_features.fit_transform(np.asarray([2020]).reshape(1, -1)))
# Out:
# array([[125.84437819]])

# %% [markdown]
# **2020年捷克劳动力成本预测值**

# %% [markdown]
# # *劳动力成本回归模型（立陶宛）*

# %%
df=pd.read_csv("/home/mw/input/Labor_data4880/labour_cost.csv")

# %%
t1=df[df['Measure']=='Index']
df=t1[t1['LOCATION']=='LTU']
plt.plot(df['TIME'],df['Value'])
plt.title('Labor cost-Lithuania')
plt.xlabel('Year') 
plt.ylabel('Labor Cost')
# Out:
# Text(0, 0.5, 'Labor Cost')
# <img src="https://cdn.kesci.com/upload/rt/9F5E10C785D34A378769DB7ABF3B8A28/rbo4qwl1xj.png">

# %%
from keras import models, layers
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x=[i for i in df['TIME']]
y=[i for i in df['Value']]
x_array=x
y_array=y
x=np.asarray(x)
y=np.asarray(y)
x = x[:, np.newaxis]
y = y[:, np.newaxis]

l=int(len(x)*.8)
x_train,x_test=x[:l],x[l:]
y_train,y_test=y[:l],y[l:]

# %%
dataset={'x':x.reshape(1,len(x))[0],'y':y.reshape(1,len(y))[0]}
df_data=pd.DataFrame(dataset)
normalized = scaler.fit_transform(df_data)
inverse = scaler.inverse_transform(normalized)
tobescaled=[]
for i in range(len(x)):
    tobescaled.append([x[i][0],y[i][0]])
tobescaled=np.asarray(tobescaled)
scaler = StandardScaler()
scaled = scaler.fit_transform(tobescaled)
x_scaled=[]
for i in range(len(x)):
    x_scaled.append([scaled[i][0]])
y_scaled=[]
for i in range(len(y)):
    y_scaled.append(scaled[i][1])

# %% [markdown]
# # 支持向量回归（SVR）

# %%
regressor = SVR(kernel='rbf')
regressor.fit(x_scaled,y_scaled)
x_scaled=x_scaled[1:]
y_scaled=y_scaled[1:]
y_pred = regressor.predict(x_scaled)
plt.scatter(x_scaled, y_scaled, color = 'magenta')
plt.plot(x_scaled, regressor.predict(x_scaled), color = 'green')
plt.title('labour cost-Lithuania')
plt.legend(['Predicted data','Actual data'])
plt.xlabel('Year', fontweight ='bold') 
plt.ylabel('Labor Cost', fontweight ='bold')
plt.show()
l=int(len(x)*.8)
x_train,x_test=x_scaled[:l],x_scaled[l:]
y_train,y_test=y_scaled[:l],y_scaled[l:]
y_svr_pred=regressor.predict(x_test)
rmse = np.sqrt(mean_squared_error(regressor.predict(x_test),y_test))
r2 = r2_score(y_test,regressor.predict(x_test))
print("RMSE=",rmse)
print("R方=",r2)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/4F6EE7C191724DA9828619D4D8C3B998/rbo4r4lf3d.png">
# RMSE= 0.2819305350031524
# R方= 0.34393802743080915

# %%
sc_x=StandardScaler()
sc_x.fit_transform(x)
sc_y=StandardScaler()
sc_y.fit_transform(y)
y_pred = sc_y.inverse_transform ((regressor.predict (sc_x.transform(np.array([[2020]])))))

# %%
y_pred
# Out:
# array([114.88052927])

# %% [markdown]
# **2020年立陶宛劳动力成本预测值**
